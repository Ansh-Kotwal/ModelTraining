# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('../DataPreProcessing/ptrain.xlsx')
test = pd.read_excel('../DataPreProcessing/ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
ridge = Ridge(alpha = 0.1)
ridge.fit(x_train , y_train )
# Out:
# Ridge(alpha=0.1)

# %%
pred = ridge.predict(x_test)
pred
# Out:
# array([13.76675948, 13.54755935, 13.31878391, ..., 14.52701422,
#        15.43967434, 16.76770973])

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.766759 -0.004074
# 1     13.529167  13.547559  0.018393
# 2     13.283333  13.318784  0.035451
# 3     13.766667  13.754579 -0.012087
# 4     14.500000  14.558983  0.058983
# ...         ...        ...       ...
# 1822  14.633333  14.637795  0.004462
# 1823  12.187500  12.185182 -0.002318
# 1824  14.504167  14.527014  0.022848
# 1825  15.412500  15.439674  0.027174
# 1826  16.754167  16.767710  0.013543
#
# [1827 rows x 3 columns]

# %%
mse = mean_squared_error(y_test, pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.0005971342271771974

# %%
mae = mean_absolute_error(y_test, pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Squared Error: 0.0193001863278656
