# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('../DataPreProcessing/ptrain.xlsx')
test = pd.read_excel('../DataPreProcessing/ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
regressor = RandomForestRegressor(n_estimators=150, random_state = 0)  # best result at max_depth :- 20  0.008125022644958076
regressor.fit(x_train, y_train)

# at 30   --> 0.00797790615575399
# Out:
# RandomForestRegressor(n_estimators=150, random_state=0)

# %%
pred = regressor.predict(x_test)
pred
# Out:
# array([13.83411111, 13.57038889, 13.36758333, ..., 14.58869444,
#        15.47480556, 16.56619444])

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.834111  0.063278
# 1     13.529167  13.570389  0.041222
# 2     13.283333  13.367583  0.084250
# 3     13.766667  13.769139  0.002472
# 4     14.500000  14.463083 -0.036917
# ...         ...        ...       ...
# 1822  14.633333  14.699306  0.065972
# 1823  12.187500  12.221444  0.033944
# 1824  14.504167  14.588694  0.084528
# 1825  15.412500  15.474806  0.062306
# 1826  16.754167  16.566194 -0.187972
#
# [1827 rows x 3 columns]

# %%
mse = mean_squared_error(y_test, pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.16520098849645615

# %%
mae = mean_absolute_error(y_test, pred)
print(f'Mean Squared Error: {mae}')
# Out:
# Mean Squared Error: 0.2560074195706387
