# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('../DataPreProcessing/ptrain.xlsx')
test = pd.read_excel('../DataPreProcessing/ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Instantiate the Lasso Regression model
lasso = Lasso(alpha=1.0)  # You can specify the alpha parameter for regularization

# Fit the model to the training data
lasso.fit(x_train_scaled, y_train)
# Out:
# Lasso()

# %%
pred = lasso.predict(x_test_scaled)
pred
# Out:
# array([14.32809836, 15.37391649, 15.24039182, ..., 14.6449324 ,
#        15.36546912, 15.65861906])

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  14.328098  0.557265
# 1     13.529167  15.373916  1.844750
# 2     13.283333  15.240392  1.957058
# 3     13.766667  14.876746  1.110079
# 4     14.500000  14.934837  0.434837
# ...         ...        ...       ...
# 1822  14.633333  14.736054  0.102721
# 1823  12.187500  13.738285  1.550785
# 1824  14.504167  14.644932  0.140766
# 1825  15.412500  15.365469 -0.047031
# 1826  16.754167  15.658619 -1.095548
#
# [1827 rows x 3 columns]

# %%
mse = mean_squared_error(y_test, pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 1.072835466954891

# %%
mae = mean_absolute_error(y_test, pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 0.7938146519462601
